# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ai_usage_dataset_new30.csv")

# %%
df.head()
# Out:
#    user_id        date        department             role tool_used  \
# 0     4174  2025-06-07        Operations          Analyst   ChatGPT
# 1     4507  2024-01-02       Engineering    Support Agent    Gemini
# 2     1860  2025-10-22       Engineering  Product Manager   Copilot
# 3     2294  2025-10-15  Customer Support        Recruiter   Copilot
# 4     2130  2024-07-25        Operations        Recruiter    Gemini
#
#   prompt_category  prompts_used      task_type  tasks_completed  \
# 0   Brainstorming             6        Testing                6
# 1       Reporting            36      Debugging                1
# 2  Email Drafting            32  Email Writing                5
# 3        Research            25         Coding                5
# 4          Coding            32      Debugging                1
#
#    time_spent_minutes  ...  data_sensitivity  security_review_required  \
# 0                  84  ...          Internal                        No
# ...

# %%
df.isnull().sum()
# Out:
# user_id                         0
# date                            0
# department                      0
# role                            0
# tool_used                       0
# prompt_category                 0
# prompts_used                    0
# task_type                       0
# tasks_completed                 0
# time_spent_minutes              0
# estimated_time_saved_minutes    0
# manual_time_estimate_minutes    0
# cost_per_hour                   0
# ai_tool_cost                    0
# accuracy_score                  0
# task_complexity                 0
# output_quality_score            0
# revision_count                  0
# error_rate                      0
# ai_adoption_level               0
# automation_level                0
# training_hours                  0
# experience_with_ai_months       0
# data_sensitivity                0
# security_review_required        0
# compliance_flag                 0
# team                            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       50000 non-null  int64
#  1   date                          50000 non-null  object
#  2   department                    50000 non-null  object
#  3   role                          50000 non-null  object
#  4   tool_used                     50000 non-null  object
#  5   prompt_category               50000 non-null  object
#  6   prompts_used                  50000 non-null  int64
#  7   task_type                     50000 non-null  object
#  8   tasks_completed               50000 non-null  int64
#  9   time_spent_minutes            50000 non-null  int64
#  10  estimated_time_saved_minutes  50000 non-null  int64
#  11  manual_time_estimate_minutes  50000 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             user_id  prompts_used  tasks_completed  time_spent_minutes  \
# count  50000.000000   50000.00000     50000.000000         50000.00000
# mean    3004.888800      19.94868         4.992160            61.74862
# std     1152.640272      11.26555         2.574784            33.27638
# min     1000.000000       1.00000         1.000000             5.00000
# 25%     2007.000000      10.00000         3.000000            33.00000
# 50%     2997.000000      20.00000         5.000000            62.00000
# 75%     4005.000000      30.00000         7.000000            91.00000
# max     4999.000000      39.00000         9.000000           119.00000
#
#        estimated_time_saved_minutes  manual_time_estimate_minutes  \
# count                  50000.000000                  50000.000000
# mean                     119.303020                    164.506840
# std                       69.310519                     78.254786
# ...

# %%
df.shape
# Out:
# (50000, 33)

# %%
df.columns
# Out:
# Index(['user_id', 'date', 'department', 'role', 'tool_used', 'prompt_category',
#        'prompts_used', 'task_type', 'tasks_completed', 'time_spent_minutes',
#        'estimated_time_saved_minutes', 'manual_time_estimate_minutes',
#        'cost_per_hour', 'ai_tool_cost', 'accuracy_score', 'task_complexity',
#        'output_quality_score', 'revision_count', 'error_rate',
#        'ai_adoption_level', 'automation_level', 'training_hours',
#        'experience_with_ai_months', 'data_sensitivity',
#        'security_review_required', 'compliance_flag', 'team', 'location',
#        'employment_type', 'salary_band', 'ai_generated_content_percent',
#        'cluster', 'user_segment'],
#       dtype='object')

# %%
df["department"].unique()
# Out:
# array(['Operations', 'Engineering', 'Customer Support', 'Sales',
#        'Finance', 'IT', 'Marketing', 'Product', 'HR'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['department'].value_counts().sort_values(ascending=False)
# Out:
# department
# Engineering         5678
# Customer Support    5629
# Finance             5612
# Marketing           5586
# Product             5533
# IT                  5529
# Sales               5502
# HR                  5493
# Operations          5438
# Name: count, dtype: int64

# %%
df['prompts_used'].sum()
# Out:
# np.int64(997434)

# %%
df['tasks_completed'].sum()
# Out:
# np.int64(249608)

# %%
df['time_spent_minutes'].sum()
# Out:
# np.int64(3087431)

# %%
df.groupby('department')['prompts_used'].sum().sort_values(ascending=False)
# Out:
# department
# Engineering         113280
# Customer Support    113192
# IT                  111469
# Finance             111455
# Marketing           111173
# Product             110853
# Sales               110055
# HR                  108931
# Operations          107026
# Name: prompts_used, dtype: int64

# %%
dept_time = df.groupby('department')['estimated_time_saved_minutes'].sum().sort_values(ascending=False)
print(dept_time)

plt.figure(figsize=(8,5))
plt.bar(dept_time.index, dept_time.values, color='skyblue')
plt.title('Total Estimated Time Saved per Department')
plt.xlabel('Department')
plt.ylabel('Estimated Time Saved (minutes)')
plt.xticks(rotation=45)
plt.ylim(640000, 680000) 

plt.show()
# Out:
# department
# Engineering         674629
# Customer Support    669756
# Finance             669074
# Marketing           663105
# HR                  661551
# Sales               661174
# Product             656560
# IT                  655299
# Operations          654003
# Name: estimated_time_saved_minutes, dtype: int64

# %%
dept_acc = df.groupby('department')['accuracy_score'].mean().sort_values(ascending=False)
print(dept_acc)

plt.figure(figsize=(8,5))
plt.bar(dept_acc.index, dept_acc.values, color='salmon')
plt.title('Average Accuracy Score per Department')
plt.xlabel('Department')
plt.ylabel('Accuracy Score')
plt.xticks(rotation=45)
plt.yscale('log')
plt.show()
# Out:
# department
# Marketing           0.753059
# HR                  0.751316
# Product             0.750983
# Finance             0.750191
# IT                  0.749470
# Sales               0.749391
# Engineering         0.749331
# Operations          0.748998
# Customer Support    0.747861
# Name: accuracy_score, dtype: float64

# %%
tool_counts = df['tool_used'].value_counts().sort_values(ascending=True)

plt.figure(figsize=(8,5))
plt.barh(tool_counts.index, tool_counts.values, color='skyblue')
plt.title('Tool Usage Frequency')
plt.xlabel('Number of Uses')
plt.ylabel('Tool')
plt.xlim(9500, 10200)
plt.show()

# %%
tool_acc = df.groupby('tool_used')['accuracy_score'].mean().sort_values(ascending=False)
print(tool_acc)

plt.figure(figsize=(8,5))
plt.bar(tool_acc.index, tool_acc.values, color='orange')
plt.title('Average Accuracy per Tool')
plt.xlabel('Tool')
plt.ylabel('Accuracy Score')
plt.ylim(0.745, 0.7545)
plt.show()
# Out:
# tool_used
# ChatGPT       0.752317
# Perplexity    0.750921
# Copilot       0.749685
# Claude        0.748829
# Gemini        0.748603
# Name: accuracy_score, dtype: float64

# %%
tool_time = df.groupby('tool_used')['estimated_time_saved_minutes'].sum().sort_values(ascending=False)

print(tool_time)

plt.figure(figsize=(8,5))
plt.bar(tool_time.index, tool_time.values, color='yellow')
plt.title('Total Estimated Time Saved per Tool')
plt.xlabel('Tool')
plt.ylabel('Estimated Time Saved (minutes)')
plt.yscale('log')

for i, value in enumerate(tool_time.values):
    plt.text(i, value, str(int(value)), ha='center')  

plt.show()
# Out:
# tool_used
# Copilot       1208197
# Perplexity    1204607
# Claude        1192650
# Gemini        1180973
# ChatGPT       1178724
# Name: estimated_time_saved_minutes, dtype: int64

# %%
df['task_type'].value_counts()
# Out:
# task_type
# Email Writing        6442
# Research             6337
# Testing              6278
# Data Analysis        6251
# Debugging            6249
# Coding               6181
# Report Generation    6176
# Documentation        6086
# Name: count, dtype: int64

# %%
task_time = df.groupby('task_type')['time_spent_minutes'].mean().sort_values(ascending=False).reset_index()

print(task_time)

plt.figure(figsize=(8,5))
plt.bar(task_time['task_type'], task_time['time_spent_minutes'], color='lightcoral')
plt.title('Average Time Spent per Task Type')
plt.xlabel('Task Type')
plt.ylabel('Time Spent (minutes)')
plt.xticks(rotation=45)
plt.ylim(61, 62.50)

plt.show()
# Out:
#            task_type  time_spent_minutes
# 0             Coding           62.298334
# 1            Testing           62.155464
# 2      Documentation           61.996385
# 3  Report Generation           61.986885
# 4           Research           61.636263
# 5      Data Analysis           61.410654
# 6      Email Writing           61.315120
# 7          Debugging           61.218275

# %%
df.groupby('task_complexity')['accuracy_score'].mean().sort_values(ascending=False)
# Out:
# task_complexity
# Medium    0.751187
# High      0.749883
# Low       0.749148
# Name: accuracy_score, dtype: float64

# %%
df['ai_adoption_level'].value_counts(ascending=False)
# Out:
# ai_adoption_level
# Medium    16814
# High      16619
# Low       16567
# Name: count, dtype: int64

# %%
df.groupby('automation_level')['estimated_time_saved_minutes'].mean().sort_values(ascending=False)
# Out:
# automation_level
# Semi-Automated     119.861138
# Fully Automated    119.053674
# Manual             118.992890
# Name: estimated_time_saved_minutes, dtype: float64

# %%
dept_cost = df.groupby('department')['cost_per_hour'].mean().sort_values(ascending=False)
print(dept_cost)

plt.figure(figsize=(8,5))
plt.bar(dept_cost.index, dept_cost.values, color='lightgreen')
plt.title('Average Cost per Hour per Department')
plt.xlabel('Department')
plt.ylabel('Cost per Hour')
plt.xticks(rotation=45)
plt.ylim(59, 60.2)
plt.show()
# Out:
# department
# Sales               60.062159
# Operations          59.737403
# Engineering         59.721557
# IT                  59.718756
# Customer Support    59.716646
# Marketing           59.587719
# Finance             59.452780
# HR                  59.399599
# Product             59.155612
# Name: cost_per_hour, dtype: float64

# %%
df.groupby('tool_used')['ai_tool_cost'].mean().sort_values(ascending=False)
# Out:
# tool_used
# Copilot       2.764956
# Gemini        2.750358
# ChatGPT       2.748396
# Claude        2.746115
# Perplexity    2.732268
# Name: ai_tool_cost, dtype: float64

# %%
dept_usage = df.groupby('department')['prompts_used'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=dept_usage.index, y=dept_usage.values)
plt.xticks(rotation=45)
plt.title("Department-wise AI Usage")
plt.xlabel("Department")
plt.ylabel("Total Prompts Used")
plt.show()

# %%
df.groupby('task_complexity')['error_rate'].mean().sort_values(ascending=False)
# Out:
# task_complexity
# Medium    0.152178
# High      0.150226
# Low       0.148708
# Name: error_rate, dtype: float64

# %%
df['productivity_gain'] = (
    df['manual_time_estimate_minutes']
    - df['time_spent_minutes']
)

dept_productivity = df.groupby('department')['productivity_gain'].mean()

plt.figure(figsize=(10,5))
sns.barplot(x=dept_productivity.index,
            y=dept_productivity.values)

plt.xticks(rotation=45)
plt.title("Department-wise Productivity Gain")
plt.xlabel("Department")
plt.ylabel("Average Productivity Gain")
plt.show()

# %%
df['prompt_category'].value_counts().sort_values(ascending=False)
# Out:
# prompt_category
# Customer Support    5656
# Research            5630
# Coding              5600
# Content Writing     5583
# Reporting           5576
# Email Drafting      5512
# Documentation       5495
# Data Analysis       5487
# Brainstorming       5461
# Name: count, dtype: int64

# %% [markdown]
# //**MODEL**

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
features = df[[
    "prompts_used",
    "time_spent_minutes",
    "estimated_time_saved_minutes",
    "accuracy_score"
]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(features)

# %%
inertia = []

for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_data)
    inertia.append(kmeans.inertia_)

plt.plot(range(1,10), inertia, marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

df["cluster"] = kmeans.fit_predict(scaled_data)

# %%
df.groupby("cluster")[[
    "prompts_used",
    "time_spent_minutes",
    "estimated_time_saved_minutes",
    "accuracy_score"
]].mean()
# Out:
#          prompts_used  time_spent_minutes  estimated_time_saved_minutes  \
# cluster
# 0           19.974102           92.819495                    116.855609
# 1           20.219147           62.205282                    118.907017
# 2           19.599072           30.855999                    122.168721
#
#          accuracy_score
# cluster
# 0              0.843352
# 1              0.599100
# 2              0.840241

# %%
def label_cluster(x):
    if x == 0:
        return "Low AI Users"
    elif x == 1:
        return "Moderate Users"
    else:
        return "High AI Users"

df["user_segment"] = df["cluster"].apply(label_cluster)

# %%
df["user_segment"].value_counts()
# Out:
# user_segment
# Moderate Users    18896
# High AI Users     15736
# Low AI Users      15368
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.countplot(data=df, x="user_segment")
plt.title("User Segmentation")
plt.show()

# %%
columns = [
    "prompts_used",
    "time_spent_minutes",
    "estimated_time_saved_minutes",
    "accuracy_score"
]

for col in columns:
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.show()

# %%
def detect_outliers(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(col, "Outliers:", len(outliers))

for col in columns:
    detect_outliers(col)
# Out:
# prompts_used Outliers: 0
# time_spent_minutes Outliers: 0
# estimated_time_saved_minutes Outliers: 0
# accuracy_score Outliers: 0

# %%
df["department"].unique()
# Out:
# array(['Operations', 'Engineering', 'Customer Support', 'Sales',
#        'Finance', 'IT', 'Marketing', 'Product', 'HR'], dtype=object)

# %%
df["role"].unique()
# Out:
# array(['Analyst', 'Support Agent', 'Product Manager', 'Recruiter',
#        'HR Specialist', 'Sales Executive', 'Developer', 'Manager',
#        'Data Scientist', 'Finance Analyst'], dtype=object)

# %%
df["tool_used"].unique()
# Out:
# array(['ChatGPT', 'Gemini', 'Copilot', 'Claude', 'Perplexity'],
#       dtype=object)

# %%
df["task_complexity"].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
import seaborn as sns

sns.histplot(df["prompts_used"], kde=True)
# Out:
# <Axes: xlabel='prompts_used', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,15))  # increase size

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
cols = [
    "prompts_used",
    "tasks_completed",
    "time_spent_minutes",
    "estimated_time_saved_minutes",
    "accuracy_score",
    "error_rate"
]

corr = df[cols].corr()

plt.figure(figsize=(8,6))

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.show()

# %%
df.columns
# Out:
# Index(['user_id', 'date', 'department', 'role', 'tool_used', 'prompt_category',
#        'prompts_used', 'task_type', 'tasks_completed', 'time_spent_minutes',
#        'estimated_time_saved_minutes', 'manual_time_estimate_minutes',
#        'cost_per_hour', 'ai_tool_cost', 'accuracy_score', 'task_complexity',
#        'output_quality_score', 'revision_count', 'error_rate',
#        'ai_adoption_level', 'automation_level', 'training_hours',
#        'experience_with_ai_months', 'data_sensitivity',
#        'security_review_required', 'compliance_flag', 'team', 'location',
#        'employment_type', 'salary_band', 'ai_generated_content_percent',
#        'cluster', 'user_segment'],
#       dtype='object')

# %%
df.to_csv("ai_usage_dataset_new30.csv", index=False)
